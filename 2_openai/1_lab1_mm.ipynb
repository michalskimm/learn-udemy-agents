# %% [markdown]
# # 2.1 Lab 1

# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace

load_dotenv(override=True)
# Out:
# True

# %%
agent = Agent(name="Jokester", instructions="You are a joke teller", model="gpt-5-nano")

# %%
with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about autonomous AI Agents")
    print(result.final_output)
# Out:
# Here are a few short jokes about autonomous AI agents. Pick your favorite!
#
# - Why did the autonomous AI agent cross the road? It followed its own objective function—no human input required.
# - What do you call an autonomous AI agent that tells jokes? A stand-up bot.
# - Why did the autonomous AI agent get a promotion? It stopped waiting for approvals and started approving itself.

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
