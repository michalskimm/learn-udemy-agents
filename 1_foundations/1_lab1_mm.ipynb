# %% [markdown]
# # Welcome

# %%
import sys
print(sys.executable)
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# /home/marekca/learn/learn-udemy-agents/.venv/bin/python
# True

# %%
import os
openai_api_key = os.getenv('OPENAI_API_KEY')
if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
from openai import OpenAI  # import the OpenAI class
openai = OpenAI()
question = "What is 2+2?"
messages = [{"role": "user", "content": question}]

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# 2 + 2 equals 4.

# %%
from IPython.display import Markdown, display
display(Markdown(answer))
# Out:
# 2 + 2 equals 4.

# %% [markdown]
# # Exercise

# %%
# call 1: business idea
messages = [{"role": "user", "content": "pick a business area that might be worth exploring for an Agentic AI opportunity"}]
response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)
business_idea = response.choices[0].message.content
print(business_idea)
# Out:
# A promising business area for an Agentic AI opportunity is **personalized healthcare management and wellness optimization**.
#
# This domain involves developing AI agents capable of proactively managing individual health objectives, such as medication adherence, lifestyle adjustments, fitness routines, dietary plans, and early detection of health issues. An agentic AI can continuously learn from user data, medical history, and evolving health goals to provide tailored recommendations, alert users to potential concerns, coordinate with healthcare providers, and even autonomously order supplies or schedule appointments.
#
# Key reasons this area is promising include:
# - Growing demand for personalized healthcare solutions.
# - Increasing availability of health data from wearables and IoT devices.
# - Potential to improve health outcomes and reduce medical costs.
# - Opportunities to integrate with existing healthcare systems and services.
#
# Exploring this area could lead to innovative AI-powered health assistants that empower individuals to take proactive control of their wellbeing.

# %%
# call 2pain point
# assistant role passes history to the user role
messages.append({"role": "assistant", "content": business_idea})
messages.append({"role": "user", "content": "present a pain-point in that industry - something challenging that might be ripe for an Agentic solution."})

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)
pain_point = response.choices[0].message.content
print(pain_point)
# Out:
# A significant pain point in personalized healthcare management is **poor medication adherence and proactive health behavior compliance**.
#
# Many patients struggle to consistently follow prescribed medication schedules, lifestyle modifications, or preventative health routines, often due to forgetfulness, lack of motivation, or difficulty understanding their health needs. This non-adherence can lead to worsening health conditions, hospitalizations, and increased medical costs.
#
# This challenge is ripe for an Agentic AI solution because:
# - An agent can autonomously monitor medication schedules, remind users, and even reorder prescriptions as needed.
# - It can adapt suggestions based on real-time data, such as activity levels or symptom reports.
# - The AI can proactively engage users with motivational messages, educational content, or behavioral nudges tailored to their specific circumstances.
# - It can coordinate with healthcare providers to ensure optimal treatment plans are followed and adjusted as necessary.
#
# Developing an intelligent, autonomous agent that actively manages and encourages adherence addresses a critical pain point, potentially improving health outcomes and reducing strain on healthcare systems.

# %%
# call 3: Agentic solution
messages.append({"role": "assistant", "content": pain_point})
messages.append({"role": "user", "content": "propose an Agentic AI solution to address this pain point."})

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)
agentic_solution = response.choices[0].message.content
print(agentic_solution)
# Out:
# To address the challenge of medication non-adherence and proactive health behavior compliance, an **Agentic AI Health Companion** can be developed with the following features:
#
# ### Proposed Solution: Autonomous Health Management Agent
#
# **1. Personalized Reminders and Motivation**
# - The AI continuously monitors medication schedules and lifestyle routines.
# - It sends timely, context-aware reminders via preferred communication channels (notifications, messages).
# - It employs motivational interviewing techniques, providing encouraging messages, educational insights, and celebrating milestones to boost user engagement.
#
# **2. Real-Time Monitoring and Feedback**
# - Integrates with wearable devices and health apps to gather data on activity levels, vital signs, and symptom reports.
# - Uses this data to assess adherence and health status, adjusting its strategies dynamically.
#
# **3. Proactive Problem-Solving**
# - Detects missed doses or deviations from prescribed routines.
# - When lapses occur, the AI initiates gentle follow-ups, offers tailored support, and suggests modifications if needed.
#
# **4. Autonomous Intervention Actions**
# - In cases of repeated non-adherence, the AI can autonomously reorder prescriptions, schedule telehealth consultations, or notify healthcare providers with concise reports.
# - It collaborates with healthcare systems to ensure timely interventions.
#
# **5. Educational and Behavioral Support**
# - Provides personalized health education to empower users, dispelling misconceptions and explaining the importance of adherence.
# - Uses behavioral nudges based on individual motivators, preferences, and prior responses.
#
# ### Benefits of the Agentic AI
# - Sustains long-term adherence through continuous, personalized, and autonomous engagement.
# - Minimizes the need for constant human oversight.
# - Enhances health outcomes and reduces hospitalizations, potentially lowering costs.
#
# This solution exemplifies an agentic AI acting proactively and autonomously to improve health behaviors, addressing a critical industry pain point effectively.
